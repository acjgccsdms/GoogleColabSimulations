# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This cell does work to ensure colab can see all edits and new files.
# Edit the import

# %%
import sys
sys.path.append('/content/drive/MyDrive/Simulation-lab')
import importlib
importlib.invalidate_caches()

import simlab.hello as hello
importlib.reload(hello)
# Out:
# <module 'simlab.hello' from '/content/drive/MyDrive/Simulation-lab/simlab/hello.py'>

# %%
import simlab.hello as hello
importlib.reload(hello)
from simlab.hello import say_hi, say_no, say_yes, cool
print(say_hi())
print(say_no())
print(say_yes())
cool()
# Out:
# Hello
# NOOOOO
# Yes
# 'cool'
